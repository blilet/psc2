# %% [markdown]
# # Transcription Simmons Institute -> DB

# %%
#pip install yt-dlp
#pip install ffmpeg
#pip install ffmpeg-python
#pip install gender-guesser
#pip install gender
import gender_guesser.detector as gender_guesser
import ffmpeg
import json
import os

# %%
from pathlib import Path
import numpy as np
import subprocess as sp
keywords = ["what", "why", "when", "where", "name", "is", "how", "do", "does", "which", "are", "could", "would",  "should", "has", "have", "whom", "whose", "?"]
def get_gender(name): #don't @ me with no heteronormative bullshit
    
    d = gender_guesser.Detector(case_sensitive=False)
    gender_prediction = d.get_gender(name)
    
    if gender_prediction == "unknown":
        return "U"
    elif gender_prediction == 'male':
        return "M"
    else:
        return "F"
def has_numbers(inputString):
    return any(char.isdigit() for char in inputString)
def strToTime(str):
    st =  str.split(':')
    return int(st[0])*3600 + int(st[1])*60 + int(float(st[2]))
def lenTirade(L):
    try: 
        start = strToTime(L[0])
        end = strToTime(L[2])
        return end - start
    except: 
        return 0
def lenSpeaker(L):
    s = 0
    for x in L:
        s+= lenTirade(x)
    return s
def mainSpeaker(d):
    speaker= 'None'
    s = 0
    for key in d.keys():
        len = lenSpeaker(d[key])
        if len >s:
            s= len
            speaker = key
    return speaker
def isQuestion(str):
    str = str.lower()
    for x in keywords:
        if x in str: return True
    return False
def mixte(str):
    if str == '0': return []
    else: return 0
def vttToDict(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            lines = file.readlines()
    except FileNotFoundError:
        print(f"Error: File '{file_path}' not found.")
        return None
    current_speaker = 'None'
    previous_speaker = 'None'
    lines = lines[4:]
    timestamps=[]
    tirades = {}
    for line in lines:
        split = line.split()
        line = line.strip()
        if '-->' in line:
            timestamps.append(line)
        elif ':' in line:
            if split[0] == split[0].upper() and not has_numbers(split[0]):
                current_speaker = split[0].replace(':','')
                begin = timestamps[-1].split('-->')[0]
                try:
                    tirades[current_speaker].append([begin, line])
                except:   
                    tirades[current_speaker]= [[begin, line]]
                if previous_speaker != 'None':
                        tirades[previous_speaker][-1].append(begin)
                previous_speaker = current_speaker
        else:
            try:
                tirades[current_speaker][-1][1] =  tirades[current_speaker][-1][1] + " - " + line
            except:
                pass
    try:
        tirades[current_speaker][-1].append(timestamps[-1].split('-->')[1].strip())
        tirades['END_STAMP'] = timestamps[-1].split('-->')[1].strip()
    except:
        pass
    return tirades
def endOfSpeech(L,prox):
    R = []
    for x in L:
        if 'APPLAUSE' in x[1]:
            R.append(x)
    try:
        end = strToTime(R[-1][2])
    except:
        end = prox
    try:
        if prox - end <10:
            end = strToTime(R[-2][2])
    except: 
        pass
    return end
def interruptions_list(L,end):
    R = []
    for x in L:
        try:
                if strToTime(x[2])< end: R.append([strToTime(x[0]), strToTime(x[2]), "U", "N"])      
        except:
            pass
    return R

# %%
download_path = Path.home() / "Downloads/cache_simmons"
download_path.mkdir(exist_ok=True, parents=True)
urls = open("urls_SIMMONS.txt", "r").readlines()
for url in urls:
    url = url.strip() #on enlève les espaces etc
    if not url:
        continue
    try:
        sp.run(['yt-dlp', '-f', '139', '--output' ,"%(id)s.m4a", url], cwd=download_path, check=True)
    except:
        pass
    try:
        sp.run(['yt-dlp', '--skip-download', '--write-description', '--output' ,"%(id)s", url], cwd=download_path, check=True)
    except:
        pass
    try:
        sp.run(['yt-dlp', '--write-sub' ,'--skip-download', '--output' ,"%(id)s",url], cwd=download_path, check=True)
    except:
        pass
# Out:
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLgKuh-lKre129zuMIQbrcTRluZIi0YMhq
# [youtube:tab] PLgKuh-lKre129zuMIQbrcTRluZIi0YMh
of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=aVdEDzq51f4
# [youtube] aVdEDzq51f4: Downloading webpage
# [youtube] aVdEDzq51f4: Downloading ios player API JSON
# [youtube] aVdEDzq51f4: Downloading android player API JSON
# [youtube] aVdEDzq51f4: Downloading m3u8 information
# [info] aVdEDzq51f4: Downloading 1 format(s): 139
# [download] Destination: aVdEDzq51f4.m4a
# [download] 100% of   23.23MiB in 00:00:01 at 15.83MiB/s
# [FixupM4a] Correcting container of "aVdEDzq51f4.m4a"
# [download] Downloading item 6 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CnWXfuMLltY
# [youtube] CnWXfuMLltY: Downloading webpage
# [youtube] CnWXfuMLltY: Downloading ios player API JSON
# [youtube] CnWXfuMLltY: Downloading android player API JSON
# [youtube] CnWXfuMLltY: Downloading m3u8 information
# [info] CnWXfuMLltY: Downloading 1 format(s): 139
# [download] Destination: CnWXfuMLltY.m4a
# [download] 100% of   21.80MiB in 00:00:01 at 16.30MiB/s
# [FixupM4a] Correcting container of "CnWXfuMLltY.m4a"
# [download] Downloading item 7 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yeLQ8uXRSAs
# [youtube] yeLQ8uXRSAs: Downloading webpage
# [youtube] yeLQ8uXRSAs: Downloading ios player API JSON
# [youtube] yeLQ8uXRSAs: Downloading android player API JSON
# [youtube] yeLQ8uXRSAs: Downloading m3u8 information
# [info] yeLQ8uXRSAs: Downloading 1 format(s): 139
# [download] Destination: yeLQ8uXRSAs.m4a
# [download] 100% of   22.35MiB in 00:00:01 at 12.97MiB/s
# [FixupM4a] Correcting container of "yeLQ8uXRSAs.m4a"
# [download] Downloading item 8 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6HigFbFEDb8
# [youtube] 6HigFbFEDb8: Downloading webpage
# [youtube] 6HigFbFEDb8: Downloading ios player API JSON
# [youtube] 6HigFbFEDb8: Downloading android player API JSON
# [youtube] 6HigFbFEDb8: Downloading m3u8 information
# [info] 6HigFbFEDb8: Downloading 1 format(s): 139
# [download] Destination: 6HigFbFEDb8.m4a
# [download] 100% of   16.75MiB in 00:00:01 at 16.28MiB/s
# [FixupM4a] Correcting container of "6HigFbFEDb8.m4a"
# [download] Downloading item 9 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=EuALvPNAGfU
# [youtube] EuALvPNAGfU: Downloading webpage
# [youtube] EuALvPNAGfU: Downloading ios player API JSON
# [youtube] EuALvPNAGfU: Downloading android player API JSON
# [youtube] EuALvPNAGfU: Downloading m3u8 information
# [info] EuALvPNAGfU: Downloading 1 format(s): 139
# [download] Destination: EuALvPNAGfU.m4a
# [download] 100% of   22.35MiB in 00:00:01 at 14.31MiB/s
# [FixupM4a] Correcting container of "EuALvPNAGfU.m4a"
# [download] Downloading item 10 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=82G8mLNnPmw
# [youtube] 82G8mLNnPmw: Downloading webpage
# [youtube] 82G8mLNnPmw: Downloading ios player API JSON
# [youtube] 82G8mLNnPmw: Downloading android player API JSON
# [download] Downloading item 11 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LHFifaxhMY4
# [youtube] LHFifaxhMY4: Downloading webpage
# ERROR: [youtube] 82G8mLNnPmw: Private video. Sign in if you've been granted access to this video
# [youtube] LHFifaxhMY4: Downloading ios player API JSON
# [youtube] LHFifaxhMY4: Downloading android player API JSON
# [download] Downloading item 12 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=
of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=aVdEDzq51f4
# [youtube] aVdEDzq51f4: Downloading webpage
# [youtube] aVdEDzq51f4: Downloading ios player API JSON
# [youtube] aVdEDzq51f4: Downloading android player API JSON
# [youtube] aVdEDzq51f4: Downloading m3u8 information
# [info] aVdEDzq51f4: Downloading 1 format(s): 248+251
# [info] Writing video description to: aVdEDzq51f4.description
# [download] Downloading item 6 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CnWXfuMLltY
# [youtube] CnWXfuMLltY: Downloading webpage
# [youtube] CnWXfuMLltY: Downloading ios player API JSON
# [youtube] CnWXfuMLltY: Downloading android player API JSON
# [youtube] CnWXfuMLltY: Downloading m3u8 information
# [info] CnWXfuMLltY: Downloading 1 format(s): 248+251
# [info] Writing video description to: CnWXfuMLltY.description
# [download] Downloading item 7 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yeLQ8uXRSAs
# [youtube] yeLQ8uXRSAs: Downloading webpage
# [youtube] yeLQ8uXRSAs: Downloading ios player API JSON
# [youtube] yeLQ8uXRSAs: Downloading android player API JSON
# [youtube] yeLQ8uXRSAs: Downloading m3u8 information
# [info] yeLQ8uXRSAs: Downloading 1 format(s): 248+251
# [info] Writing video description to: yeLQ8uXRSAs.description
# [download] Downloading item 8 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6HigFbFEDb8
# [youtube] 6HigFbFEDb8: Downloading webpage
# [youtube] 6HigFbFEDb8: Downloading ios player API JSON
# [youtube] 6HigFbFEDb8: Downloading android player API JSON
# [youtube] 6HigFbFEDb8: Downloading m3u8 information
# [info] 6HigFbFEDb8: Downloading 1 format(s): 248+251
# [info] Writing video description to: 6HigFbFEDb8.description
# [download] Downloading item 9 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=EuALvPNAGfU
# [youtube] EuALvPNAGfU: Downloading webpage
# [youtube] EuALvPNAGfU: Downloading ios player API JSON
# [youtube] EuALvPNAGfU: Downloading android player API JSON
# [youtube] EuALvPNAGfU: Downloading m3u8 information
# [info] EuALvPNAGfU: Downloading 1 format(s): 248+251
# [info] Writing video description to: EuALvPNAGfU.description
# [download] Downloading item 10 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=82G8mLNnPmw
# [youtube] 82G8mLNnPmw: Downloading webpage
# [youtube] 82G8mLNnPmw: Downloading ios player API JSON
# [youtube] 82G8mLNnPmw: Downloading android player API JSON
# [download] Downloading item 11 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LHFifaxhMY4
# [youtube] LHFifaxhMY4: Downloading webpage
# ERROR: [youtube] 82G8mLNnPmw: Private video. Sign in if you've been granted access to this video
# [youtube] LHFifaxhMY4: Downloading ios player API JSON
# [youtube] LHFifaxhMY4: Downloading android player API JSON
# [download] Downloading item 12 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ItyFoiqHFJc
# [youtube] ItyFoiqHFJc: Downloading webpage
# ERROR: [youtube] LHFifaxhMY4: Private video. Sign in if you've been granted access to this video
# [youtube] ItyFoiqHFJc: Downloading ios player API JSON
# [youtube] ItyFoiqHFJc: Downloading android player API JSON
# [youtube] ItyFoiqHFJc: Downloading m3u8 information
# [info] ItyFoiqHFJc: Downloading 1 format(s): 248+251
# [info] Writing video description to: ItyFoiqHFJc.description
# [download] Downloading item 13 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=
Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: aVdEDzq51f4.en-j3PyPqV-e1s.vtt
# [download] Destination: aVdEDzq51f4.en-j3PyPqV-e1s.vtt
# [download] 100% of  103.90KiB in 00:00:00 at 3.11MiB/s
# [download] Downloading item 6 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CnWXfuMLltY
# [youtube] CnWXfuMLltY: Downloading webpage
# [youtube] CnWXfuMLltY: Downloading ios player API JSON
# [youtube] CnWXfuMLltY: Downloading android player API JSON
# [youtube] CnWXfuMLltY: Downloading m3u8 information
# [info] CnWXfuMLltY: Downloading subtitles: en-j3PyPqV-e1s
# [info] CnWXfuMLltY: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: CnWXfuMLltY.en-j3PyPqV-e1s.vtt
# [download] Destination: CnWXfuMLltY.en-j3PyPqV-e1s.vtt
# [download] 100% of   69.19KiB in 00:00:00 at 664.03KiB/s
# [download] Downloading item 7 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yeLQ8uXRSAs
# [youtube] yeLQ8uXRSAs: Downloading webpage
# [youtube] yeLQ8uXRSAs: Downloading ios player API JSON
# [youtube] yeLQ8uXRSAs: Downloading android player API JSON
# [youtube] yeLQ8uXRSAs: Downloading m3u8 information
# [info] yeLQ8uXRSAs: Downloading subtitles: en-j3PyPqV-e1s
# [info] yeLQ8uXRSAs: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: yeLQ8uXRSAs.en-j3PyPqV-e1s.vtt
# [download] Destination: yeLQ8uXRSAs.en-j3PyPqV-e1s.vtt
# [download] 100% of   68.26KiB in 00:00:00 at 2.75MiB/s
# [download] Downloading item 8 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6HigFbFEDb8
# [youtube] 6HigFbFEDb8: Downloading webpage
# [youtube] 6HigFbFEDb8: Downloading ios player API JSON
# [youtube] 6HigFbFEDb8: Downloading android player API JSON
# [youtube] 6HigFbFEDb8: Downloading m3u8 information
# [info] 6HigFbFEDb8: Downloading subtitles: en-j3PyPqV-e1s
# [info] 6HigFbFEDb8: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: 6HigFbFEDb8.en-j3PyPqV-e1s.vtt
# [download] Destination: 6HigFbFEDb8.en-j3PyPqV-e1s.vtt
# [download] 100% of   51.92KiB in 00:00:00 at 2.05MiB/s
# [download] Downloading item 9 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=EuALvPNAGfU
# [youtube] EuALvPNAGfU: Downloading webpage
# [youtube] EuALvPNAGfU: Downloading ios player API JSON
# [youtube] EuALvPNAGfU: Downloading android player API JSON
# [youtube] EuALvPNAGfU: Downloading m3u8 information
# [info] EuALvPNAGfU: Downloading subtitles: en-j3PyPqV-e1s
# [info] EuALvPNAGfU: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: EuALvPNAGfU.en-j3PyPqV-e1s.vtt
# [download] Destination: EuALvPNAGfU.en-j3PyPqV-e1s.vtt
# [download] 100% of   95.13KiB in 00:00:00 at 945.43KiB/s
# [download] Downloading item 10 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=82G8mLNnPmw
# [youtube] 82G8mLNnPmw: Downloading webpage
# [youtube] 82G8mLNnPmw: Downloading ios player API JSON
# [youtube] 82G8mLNnPmw: Downloading android player API JSON
# [download] Downloading item 11 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LHFifaxhMY4
# [youtube] LHFifaxhMY4: Downloading webpage
# [youtube] LHFifaxhMY4: Downloading ios player API JSON
# ERROR: [youtube] 82G8mLNnPmw: Private video. Sign in if you've been granted access to this video
# ERROR: [youtube] LHFifaxhMY4: Private video. Sign in if you've been granted access to this video
# [youtube] LHFifaxhMY4: Downloading android player API JSON
# [download] Downloading item 12 of 19
# [youtube] Extracting URL: https://www.youtube.com/watch?v=
of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ltN4QnnBzzQ
# [youtube] ltN4QnnBzzQ: Downloading webpage
# [youtube] ltN4QnnBzzQ: Downloading ios player API JSON
# [youtube] ltN4QnnBzzQ: Downloading android player API JSON
# [youtube] ltN4QnnBzzQ: Downloading m3u8 information
# [info] ltN4QnnBzzQ: Downloading 1 format(s): 139
# [download] Destination: ltN4QnnBzzQ.m4a
# [download] 100% of    9.91MiB in 00:00:02 at 3.55MiB/s
# [FixupM4a] Correcting container of "ltN4QnnBzzQ.m4a"
# [download] Downloading item 10 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=iCcysaa2Y2A
# [youtube] iCcysaa2Y2A: Downloading webpage
# [youtube] iCcysaa2Y2A: Downloading ios player API JSON
# [youtube] iCcysaa2Y2A: Downloading android player API JSON
# [youtube] iCcysaa2Y2A: Downloading m3u8 information
# [info] iCcysaa2Y2A: Downloading 1 format(s): 139
# [download] Destination: iCcysaa2Y2A.m4a
# [download] 100% of    9.63MiB in 00:00:01 at 5.16MiB/s
# [FixupM4a] Correcting container of "iCcysaa2Y2A.m4a"
# [download] Downloading item 11 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6VsAYb8DuLg
# [youtube] 6VsAYb8DuLg: Downloading webpage
# [youtube] 6VsAYb8DuLg: Downloading ios player API JSON
# [youtube] 6VsAYb8DuLg: Downloading android player API JSON
# [youtube] 6VsAYb8DuLg: Downloading m3u8 information
# [info] 6VsAYb8DuLg: Downloading 1 format(s): 139
# [download] Destination: 6VsAYb8DuLg.m4a
# [download] 100% of   10.10MiB in 00:00:03 at 3.08MiB/s
# [FixupM4a] Correcting container of "6VsAYb8DuLg.m4a"
# [download] Downloading item 12 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=FqLCImQNpeg
# [youtube] FqLCImQNpeg: Downloading webpage
# [youtube] FqLCImQNpeg: Downloading ios player API JSON
# [youtube] FqLCImQNpeg: Downloading android player API JSON
# [youtube] FqLCImQNpeg: Downloading m3u8 information
# [info] FqLCImQNpeg: Downloading 1 format(s): 139
# [download] Destination: FqLCImQNpeg.m4a
# [download] 100% of   17.12MiB in 00:00:03 at 4.37MiB/s
# [FixupM4a] Correcting container of "FqLCImQNpeg.m4a"
# [download] Downloading item 13 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=GLE3hjDRbQw
# [youtube] GLE3hjDRbQw: Downloading webpage
# [youtube] GLE3hjDRbQw: Downloading ios player API JSON
# [youtube] GLE3hjDRbQw: Downloading android player API JSON
# [youtube] GLE3hjDRbQw: Downloading m3u8 information
# [info] GLE3hjDRbQw: Downloading 1 format(s): 139
# [download] Destination: GLE3hjDRbQw.m4a
# [download] 100% of   21.58MiB in 00:00:06 at 3.12MiB/s
# [FixupM4a] Correcting container of "GLE3hjDRbQw.m4a"
# [download] Downloading item 14 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yWSgcyPgrSQ
# [youtube] yWSgcyPgrSQ: Downloading webpage
# [youtube] yWSgcyPgrSQ: Downloading ios player API JSON
# [youtube] yWSgcyPgrSQ: Downloading android player API JSON
# [youtube] yWSgcyPgrSQ: Downloading m3u8 information
# [info] yWSgcyPgrSQ: Downloading 1 format(s): 139
# [download] Destination: yWSgcyPgrSQ.m4a
# [download] 100% of   21.01MiB in 00:00:05 at 3.95MiB/s
# [FixupM4a] Correcting container of "yWSgcyPgrSQ.m4a"
# [download] Downloading item 15 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OhiOEG0zbOs
# [youtube] OhiOEG0zbOs: Downloading webpage
# [youtube] OhiOEG0zbOs: Downloading ios player API JSON
# [youtube] OhiOEG0zbOs: Downloading android player API JSON
# [youtube] OhiOEG0zbOs: Downloading m3u8 information
# [info] OhiOEG0zbOs: Downloading 1 format(s): 139
# [download] Destination: OhiOEG0zbOs.m4a
# [download] 100% of   11.25MiB in 00:00:03 at 3.68MiB/s
# [FixupM4a] Correcting container of "OhiOEG0zbOs.m4a"
# [download] Downloading item 16 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vezej4nvkw8
# [youtube] vezej4nvkw8: Downloading webpage
# [youtube] vezej4nvkw8: Downloading ios player API JSON
# [youtube] vezej4nvkw8: Downloading android player API JSON
# [youtube] vezej4nvkw8: Downloading m3u8 information
# [info] vezej4nvkw8: Downloading 1 format(s): 139
# [download] Destination: vezej4nvkw8.m4a
# [download] 100% of   11.33MiB in 00:00:04 at 2.40MiB/s
# [FixupM4a] Correcting container of "vezej4nvkw8.m4a"
# [download] Downloading item 17 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=ii6TMtotLSA
# [youtube] ii6TMtotLSA: Downloading webpage
# [youtube] ii6TMtotLSA: Downloading ios player API JSON
# [youtube] ii6TMtotLSA: Downloading android player API JSON
# [youtube] ii6TMtotLSA: Downloading m3u8 information
# [info] ii6TMtotLSA: Downloading 1 format(s): 139
# [download] Destination: ii6TMtotLSA.m4a
# [download] 100% of   19.42MiB in 00:00:05 at 3.85MiB/s
# [FixupM4a] Correcting container of "ii6TMtotLSA.m4a"
# [download] Downloading item 18 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=HfoJFOe1oaY
# [youtube] HfoJFOe1oaY: Downloading webpage
# [youtube] HfoJFOe1oaY: Downloading ios player API JSON
# [youtube] HfoJFOe1oaY: Downloading android player API JSON
# [youtube] HfoJFOe1oaY: Downloading m3u8 information
# [info] HfoJFOe1oaY: Downloading 1 format(s): 139
# [download] Destination: HfoJFOe1oaY.m4a
# [download] 100% of   21.04MiB in 00:00:06 at 3.40MiB/s
# [FixupM4a] Correcting container of "HfoJFOe1oaY.m4a"
# [download] Downloading item 19 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Rb0vhnNWLwM
# [youtube] Rb0vhnNWLwM: Downloading webpage
# [youtube] Rb0vhnNWLwM: Downloading ios player API JSON
# [youtube] Rb0vhnNWLwM: Downloading android player API JSON
# [youtube] Rb0vhnNWLwM: Downloading m3u8 information
# [info] Rb0vhnNWLwM: Downloading 1 format(s): 139
# [download] Destination: Rb0vhnNWLwM.m4a
# [download] 100% of   19.99MiB in 00:00:03 at 5.83MiB/s
# [FixupM4a] Correcting container of "Rb0vhnNWLwM.m4a"
# [download] Downloading item 20 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yc7AnljV1N4
# [youtube] yc7AnljV1N4: Downloading webpage
# [youtube] yc7AnljV1N4: Downloading ios player API JSON
# [youtube] yc7AnljV1N4: Downloading android player API JSON
# [youtube] yc7AnljV1N4: Downloading m3u8 information
# [info] yc7AnljV1N4: Downloading 1 format(s): 139
# [download] Destination: yc7AnljV1N4.m4a
# [download] 100% of   10.18MiB in 00:00:03 at 3.06MiB/s
# [FixupM4a] Correcting container of "yc7AnljV1N4.m4a"
# [download] Downloading item 21 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=uqv3tq_1tFA
# [youtube] uqv3tq_1tFA: Downloading webpage
# [youtube] uqv3tq_1tFA: Downloading ios player API JSON
# [youtube] uqv3tq_1tFA: Downloading android player API JSON
# [youtube] uqv3tq_1tFA: Downloading m3u8 information
# [info] uqv3tq_1tFA: Downloading 1 format(s): 139
# [download] Destination: uqv3tq_1tFA.m4a
# [download] 100% of   11.30MiB in 00:00:03 at 3.35MiB/s
# [FixupM4a] Correcting container of "uqv3tq_1tFA.m4a"
# [download] Downloading item 22 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=gsQBqggnkRs
# [youtube] gsQBqggnkRs: Downloading webpage
# [youtube] gsQBqggnkRs: Downloading ios player API JSON
# [youtube] gsQBqggnkRs: Downloading android player API JSON
# [youtube] gsQBqggnkRs: Downloading m3u8 information
# [info] gsQBqggnkRs: Downloading 1 format(s): 139
# [download] Destination: gsQBqggnkRs.m4a
# [download] 100% of   20.57MiB in 00:00:05 at 3.61MiB/s
# [FixupM4a] Correcting container of "gsQBqggnkRs.m4a"
# [download] Downloading item 23 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=yElye4AlDSg
# [youtube] yElye4AlDSg: Downloading webpage
# [youtube] yElye4AlDSg: Downloading ios player API JSON
# [youtube] yElye4AlDSg: Downloading android player API JSON
# [youtube] yElye4AlDSg: Downloading m3u8 information
# [info] yElye4AlDSg: Downloading 1 format(s): 139
# [download] Destination: yElye4AlDSg.m4a
# [download] 100% of   13.44MiB in 00:00:03 at 3.66MiB/s
# [FixupM4a] Correcting container of "yElye4AlDSg.m4a"
# [download] Finished downloading playlist: Optimization and Algorithm Design
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLgKuh-lKre10j3DeR88lo-CwAxeSH2fPM
# [youtube:tab] PLgKuh-lKre10j3DeR88lo-CwAxeSH2fPM: Downloading webpage
# WARNING: [youtube:tab] YouTube said: INFO - 1 unavailable video is hidden
# [youtube:tab] PLgKuh-lKre10j3DeR88lo-CwAxeSH2fPM: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Optimization and Algorithm Design
# [youtube:tab] PLgKuh-lKre10j3DeR88lo-CwAxeSH2fPM page 1: Downloading API JSON
# [youtube:tab] PLgKuh-lKre10j3DeR88lo-CwAxeSH2fPM page 1: Downloading API JSON
# [youtube:tab] PLgKuh-lKre10j3DeR88lo-CwAxeSH2fPM page 1: Downloading API JSON
# [youtube:tab] PLgKuh-lKre10j3DeR88lo-CwAxeSH2fPM page 1: Downloading API JSON
# [info] Writing playlist description to: PLgKuh-lKre10j3DeR88lo-CwAxeSH2fPM.description
# [youtube:tab] Playlist Optimization and Algorithm Design: Downloading 23 items of 23
# [download] Downloading item 1 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=DM17pUIlnB0
# [youtube] DM17pUIlnB0: Downloading webpage
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# [youtube] DM17pUIlnB0: Downloading ios player API JSON
# [youtube] DM17pUIlnB0: Downloading android player API JSON
# [youtube] DM17pUIlnB0: Downloading m3u8 information
# [info] DM17pUIlnB0: Downloading 1 format(s): 248+251
# [info] Writing video description to: DM17pUIlnB0.description
# [download] Downloading item 2 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=1rngY9Gmu2I
# [youtube] 1rngY9Gmu2I: Downloading webpage
# [youtube] 1rngY9Gmu2I: Downloading ios player API JSON
# [youtube] 1rngY9Gmu2I: Downloading android player API JSON
# [youtube] 1rngY9Gmu2I: Downloading m3u8 information
# [info] 1rngY9Gmu2I: Downloading 1 format(s): 137+251
# [info] Writing video description to: 1rngY9Gmu2I.description
# [download] Downloading item 3 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fMMy2yYfZ1A
# [youtube] fMMy2yYfZ1A: Downloading webpage
# [youtube] fMMy2yYfZ1A: Downloading ios player API JSON
# [youtube] fMMy2yYfZ1A: Downloading android player API JSON
# [youtube] fMMy2yYfZ1A: Downloading m3u8 information
# [info] fMMy2yYfZ1A: Downloading 1 format(s): 248+251
# [info] Writing video description to: fMMy2yYfZ1A.description
# [download] Downloading item 4 of 23
# [youtube] Extracting URL: https://www.youtube.com/watch?v=vowUd1mR6a0
# [youtube] vowUd1mR6a0: Downloading webpage
# [youtube] vowUd1mR6a0: Downloading ios player API JSON
# [youtube] vowUd1mR6a0: Downloading android player API JSON
# [youtube] vowUd1mR6a0: Downloading m3u8 information
# [info] vowUd1mR6a0: Downloading 1 format(s): 137+251
# ...
# [info] CyHy559ebyg: Downloading 1 format(s): 248+251
# [info] Writing video description to: CyHy559ebyg.description
# [download] Downloading item 24 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fU4F_g5bsNc
# [youtube] fU4F_g5bsNc: Downloading webpage
# [youtube] fU4F_g5bsNc: Downloading ios player API JSON
# [youtube] fU4F_g5bsNc: Downloading android player API JSON
# [youtube] fU4F_g5bsNc: Downloading m3u8 information
# [info] fU4F_g5bsNc: Downloading 1 format(s): 248+251
# [info] Writing video description to: fU4F_g5bsNc.description
# [download] Finished downloading playlist: Sketching and Algorithm Design
# [youtube:tab] Extracting URL: https://www.youtube.com/playlist?list=PLgKuh-lKre10-e2TWPCB0JdacFEnHHS31
# [youtube:tab] PLgKuh-lKre10-e2TWPCB0JdacFEnHHS31: Downloading webpage
# [youtube:tab] PLgKuh-lKre10-e2TWPCB0JdacFEnHHS31: Redownloading playlist API JSON with unavailable videos
# [download] Downloading playlist: Sketching and Algorithm Design
# [youtube:tab] PLgKuh-lKre10-e2TWPCB0JdacFEnHHS31 page 1: Downloading API JSON
# [youtube:tab] PLgKuh-lKre10-e2TWPCB0JdacFEnHHS31 page 1: Downloading API JSON
# [youtube:tab] PLgKuh-lKre10-e2TWPCB0JdacFEnHHS31 page 1: Downloading API JSON
# [youtube:tab] PLgKuh-lKre10-e2TWPCB0JdacFEnHHS31 page 1: Downloading API JSON
# [youtube:tab] Playlist Sketching and Algorithm Design: Downloading 24 items of 24
# [download] Downloading item 1 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=xiDdXU-_zWU
# [youtube] xiDdXU-_zWU: Downloading webpage
# WARNING: [youtube:tab] Incomplete data received. Retrying (1/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (2/3)...
# WARNING: [youtube:tab] Incomplete data received. Retrying (3/3)...
# WARNING: [youtube:tab] Incomplete data received. Giving up after 3 retries
# [youtube] xiDdXU-_zWU: Downloading ios player API JSON
# [youtube] xiDdXU-_zWU: Downloading android player API JSON
# [youtube] xiDdXU-_zWU: Downloading m3u8 information
# [info] xiDdXU-_zWU: Downloading subtitles: en-j3PyPqV-e1s
# [info] xiDdXU-_zWU: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: xiDdXU-_zWU.en-j3PyPqV-e1s.vtt
# [download] Destination: xiDdXU-_zWU.en-j3PyPqV-e1s.vtt
# [download] 100% of   98.02KiB in 00:00:00 at 2.82MiB/s
# [download] Downloading item 2 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v
Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: M50gkD0r7M4.en-j3PyPqV-e1s.vtt
# [download] Destination: M50gkD0r7M4.en-j3PyPqV-e1s.vtt
# [download] 100% of   82.73KiB in 00:00:00 at 3.01MiB/s
# [download] Downloading item 8 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Ooyidh88_AA
# [youtube] Ooyidh88_AA: Downloading webpage
# [youtube] Ooyidh88_AA: Downloading ios player API JSON
# [youtube] Ooyidh88_AA: Downloading android player API JSON
# [youtube] Ooyidh88_AA: Downloading m3u8 information
# [info] Ooyidh88_AA: Downloading subtitles: en-j3PyPqV-e1s
# [info] Ooyidh88_AA: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: Ooyidh88_AA.en-j3PyPqV-e1s.vtt
# [download] Destination: Ooyidh88_AA.en-j3PyPqV-e1s.vtt
# [download] 100% of   47.21KiB in 00:00:00 at 2.08MiB/s
# [download] Downloading item 9 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6nyH32X_p-s
# [youtube] 6nyH32X_p-s: Downloading webpage
# [youtube] 6nyH32X_p-s: Downloading ios player API JSON
# [youtube] 6nyH32X_p-s: Downloading android player API JSON
# [youtube] 6nyH32X_p-s: Downloading m3u8 information
# [info] 6nyH32X_p-s: Downloading subtitles: en-j3PyPqV-e1s
# [info] 6nyH32X_p-s: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: 6nyH32X_p-s.en-j3PyPqV-e1s.vtt
# [download] Destination: 6nyH32X_p-s.en-j3PyPqV-e1s.vtt
# [download] 100% of   39.07KiB in 00:00:00 at 1.84MiB/s
# [download] Downloading item 10 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=MF7QXrvowWo
# [youtube] MF7QXrvowWo: Downloading webpage
# [youtube] MF7QXrvowWo: Downloading ios player API JSON
# [youtube] MF7QXrvowWo: Downloading android player API JSON
# [youtube] MF7QXrvowWo: Downloading m3u8 information
# [info] MF7QXrvowWo: Downloading subtitles: en-j3PyPqV-e1s
# [info] MF7QXrvowWo: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: MF7QXrvowWo.en-j3PyPqV-e1s.vtt
# [download] Destination: MF7QXrvowWo.en-j3PyPqV-e1s.vtt
# [download] 100% of   52.07KiB in 00:00:00 at 2.38MiB/s
# [download] Downloading item 11 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=huQ3KVoiGOk
# [youtube] huQ3KVoiGOk: Downloading webpage
# [youtube] huQ3KVoiGOk: Downloading ios player API JSON
# [youtube] huQ3KVoiGOk: Downloading android player API JSON
# [youtube] huQ3KVoiGOk: Downloading m3u8 information
# [info] huQ3KVoiGOk: Downloading subtitles: en-j3PyPqV-e1s
# [info] huQ3KVoiGOk: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: huQ3KVoiGOk.en-j3PyPqV-e1s.vtt
# [download] Destination: huQ3KVoiGOk.en-j3PyPqV-e1s.vtt
# [download] 100% of   92.60KiB in 00:00:00 at 807.88KiB/s
# [download] Downloading item 12 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=bILurZvDaYI
# [youtube] bILurZvDaYI: Downloading webpage
# [youtube] bILurZvDaYI: Downloading ios player API JSON
# [youtube] bILurZvDaYI: Downloading android player API JSON
# [youtube] bILurZvDaYI: Downloading m3u8 information
# [info] bILurZvDaYI: Downloading subtitles: en-j3PyPqV-e1s
# [info] bILurZvDaYI: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to
Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: M_C1zf405PI.en-j3PyPqV-e1s.vtt
# [download] Destination: M_C1zf405PI.en-j3PyPqV-e1s.vtt
# [download] 100% of   73.85KiB in 00:00:00 at 2.28MiB/s
# [download] Downloading item 23 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=CyHy559ebyg
# [youtube] CyHy559ebyg: Downloading webpage
# [youtube] CyHy559ebyg: Downloading ios player API JSON
# [youtube] CyHy559ebyg: Downloading android player API JSON
# [youtube] CyHy559ebyg: Downloading m3u8 information
# [info] CyHy559ebyg: Downloading subtitles: en-j3PyPqV-e1s
# [info] CyHy559ebyg: Downloading 1 format(s): 248+251
# [info] Writing video subtitles to: CyHy559ebyg.en-j3PyPqV-e1s.vtt
# [download] Destination: CyHy559ebyg.en-j3PyPqV-e1s.vtt
# [download] 100% of   55.05KiB in 00:00:00 at 526.41KiB/s
# [download] Downloading item 24 of 24
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fU4F_g5bsNc
# [youtube] fU4F_g5bsNc: Downloading webpage
# [youtube] fU4F_g5bsNc: Downloading ios player API JSON
# [youtube] fU4F_g5bsNc: Downloading android player API JSON
# [youtube] fU4F_g5bsNc: Downloading m3u8 information
# [info] fU4F_g5bsNc: Downloading 1 format(s): 248+251
# [info] There are no subtitles for the requested languages
# [download] Finished downloading playlist: Sketching and Algorithm Design

# %%
in_folder = Path.home()/"Downloads/cache_simmons"
out_folder= Path.home()/"Downloads/wav_simmons"
out_folder.mkdir(exist_ok=True, parents=True)
for file in in_folder.iterdir():
    if file.suffix != ".m4a":
        continue
    sp.run(["ffmpeg", "-y", "-i", file, "-ar", "16000", "-ac", "1", out_folder/(file.stem + ".wav")], check=True)
# Out:
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.1.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/timou/Downloads/cache_simmons/MF7QXrvowWo.m4a':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:43:09.91, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0[0x1](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/Users/timou/Downloads/wav_simmons/MF7QXrvowWo.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     ISFT            : Lavf60.16.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 pcm_s16le
# [out#0/wav @ 0x600000640300] video:0kB audio:80935kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000094%
# size=   80935kB time=00:43:09.90 bitrate= 256.0kbits/s speed= 519x
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.1.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/timou/Downloads/cache_simmons/c10tC86rQYs.m4a':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:52:37.73, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0[0x1](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/Users/timou/Downloads/wav_simmons/c10tC86rQYs.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     ISFT            : Lavf60.16.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 pcm_s16le
# [out#0/wav @ 0x6000000980c0] video:0kB audio:98679kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000077%
# size=   98679kB time=00:52:37.72 bitrate= 256.0kbits/s speed= 520x
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.1.0.2.5)
#   configuration: --prefix=/opt/homebrew/Cellar/ffmpeg/6.1.1_3 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags='-Wl,-ld_classic' --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libharfbuzz --enable-libjxl --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libssh --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libopenvino --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox --enable-audiotoolbox --enable-neon
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
#   libpostproc    57.  3.100 / 57.  3.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/Users/timou/Downloads/cache_simmons/WwVwfOF2sEM.m4a':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     encoder         : Lavf60.16.100
#   Duration: 01:02:31.69, start: 0.000000, bitrate: 48 kb/s
#   Stream #0:0[0x1](eng): Audio: aac (HE-AAC) (mp4a / 0x6134706D), 44100 Hz, stereo, fltp, 48 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/Users/timou/Downloads/wav_simmons/WwVwfOF2sEM.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2mp41
#     ISFT            : Lavf60.16.100
#   Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 16000 Hz, mono, s16, 256 kb/s (default)
#     Metadata:
#       handler_name    : ISO Media file produced by Google Inc.
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc60.31.102 pcm_s16le
# [out#0/wav @ 0x6000014d43c0] video:0kB audio:5631kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001353%
# size=    5631kB time=00:03:00.13 bitrate= 256.1kbits/s speed= 511x
# Exiting normally, received signal 2.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[219], line 7
#       5 if file.suffix != ".m4a":
#       6     continue
# ----> 7 sp.run(["ffmpeg", "-y", "-i", file, "-ar", "16000", "-ac", "1", out_folder/(file.stem + ".wav")], check=True)
#
# File ~/anaconda3/envs/psc/lib/python3.11/subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File ~/anaconda3/envs/psc/lib/python3.11/subprocess.py:1201, in Popen.communicate(self, input, timeout)
#    1199         stderr = self.stderr.read()
#    1200         self.stderr.close()
# -> 1201     self.wait()
#    1202 else:
#    1203     if timeout is not None:
#
# File ~/anaconda3/envs/psc/lib/python3.11/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File ~/anaconda3/envs/psc/lib/python3.11/subprocess.py:2046, in Popen._wait(self, timeout)
#    2044 if self.returncode is not None:
#    2045     break  # Another thread waited.
# -> 2046 (pid, sts) = self._try_wait(0)
#    2047 # Check the pid and loop as waitpid has been known to
#    2048 # return 0 even without WNOHANG in odd situations.
#    2049 # http://bugs.python.org/issue14396.
#    2050 if pid == self.pid:
#
# File ~/anaconda3/envs/psc/lib/python3.11/subprocess.py:2004, in Popen._try_wait(self, wait_flags)
#    2002 """All callers to this function MUST hold self._waitpid_lock."""
#    2003 try:
# -> 2004     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2005 except ChildProcessError:
#    2006     # This happens if SIGCLD is set to be ignored or waiting
#    2007     # for child processes has otherwise been disabled for our
#    2008     # process.  This child is dead, we can't get the status.
#    2009     pid = self.pid
#
# KeyboardInterrupt:

# %%
out_J = out_json = in_folder/"json"
out_J.mkdir(exist_ok=True, parents=True)
for file in in_folder.iterdir():
    if file.suffix != ".vtt":
        continue
    uuid = file.stem.split('.')[0]
    path = str(out_folder) + '/'+uuid + '.wav'
    dict = vttToDict(file)
    speaker = mainSpeaker(dict)
    start = strToTime(dict[speaker][0][0])
    end = endOfSpeech(dict[speaker],strToTime(dict['END_STAMP']))
    path_description = str(in_folder)  + '/'+uuid + '.description'
    uuid_json = uuid+ '.json'
    out_json = in_folder/"json"/uuid_json
    try:
        with open(path_description, 'r', encoding='utf-8') as file:
            line = file.readline()
    except FileNotFoundError:
        continue
    if 'Auth' in line:
        line = line.split(' ')[1]
    else:
        line = line.split(' ')[0]
    genderS = get_gender(line)
    if 'AUDIENCE' in dict.keys():
        interruptions = interruptions_list(dict['AUDIENCE'],end)
    else: 
        try:
            interruptions = interruptions_list(dict['STUDENT'],end)
        except:
            continue
    to_JSON = {'path': (path, uuid), 'gender':genderS, 'start':int(start), 'end':end, 'num_interruptions':len(interruptions), 'interruptions':interruptions}
    json_d = json.dumps(to_JSON, indent = 2)
    with open(out_json, 'w') as f:
            f.write(json_d)

# %%
python_objects = []
for json_file in out_J.iterdir():
        try:
            with open(json_file, "r") as f:
                python_objects.append(json.load(f))
            # Dump all the Python objects into a single JSON file.
        except:
            pass
with open('database_SIMMONS.json', "w") as f:
    json.dump(python_objects, f, indent=4)
print('Stored in where ipynb file is.')
# Out:
# Stored in where ipynb file is.
