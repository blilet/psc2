# %% [markdown]
# ## Gender Recognition using ANN

# %%
# Install NumPy
# %pip install numpy

# Install Pandas
# %pip install pandas

# Install tqdm for progress bars
# %pip install tqdm

# Install TensorFlow for deep learning models
# %pip install tensorflow

# Install Librosa for audio analysis
# %pip install librosa

# Install SciPy for scientific computing
# %pip install scipy

# Install PyDub for audio file manipulation
# %pip install pydub

# Install Matplotlib for plotting
# %pip install matplotlib

# Install scikit-learn for machine learning tools
# %pip install scikit-learn

# Install resampy for resampling purposes
# %pip install resampy
# Out:
# Requirement already satisfied: numpy in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (1.23.5)
# ^C
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/__main__.py", line 24, in <module>
#     sys.exit(_main())
#              ^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/cli/main.py", line 79, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/cli/base_command.py", line 101, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/cli/base_command.py", line 236, in _main
#     self.handle_pip_version_check(options)
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/cli/req_command.py", line 191, in handle_pip_version_check
#     pip_self_version_check(session, options)
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/self_outdated_check.py", line 230, in pip_self_version_check
#     upgrade_prompt = _self_version_check_logic(
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/self_outdated_check.py", line 193, in _self_version_check_logic
#     remote_version_str = get_remote_version()
#                          ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/self_outdated_check.py", line 177, in _get_current_remote_pip_version
#     best_candidate = finder.find_best_candidate("pip").best_candidate
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/index/package_finder.py", line 890, in find_best_candidate
#     candidates = self.find_all_candidates(project_name)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/index/package_finder.py", line 831, in find_all_candidates
#     page_candidates = list(page_candidates_it)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/index/sources.py", line 134, in page_candidates
#     yield from self._candidates_from_page(self._link)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/index/package_finder.py", line 791, in process_project_url
#     index_response = self._link_collector.fetch_response(project_url)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/index/collector.py", line 461, in fetch_response
#     return _get_index_content(location, session=self.session)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/index/collector.py", line 364, in _get_index_content
#     resp = _get_simple_response(url, session=session)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/index/collector.py", line 135, in _get_simple_response
#     resp = session.get(
#            ^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_vendor/requests/sessions.py", line 602, in get
#     return self.request("GET", url, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_internal/network/session.py", line 519, in request
#     return super().request(method, url, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_vendor/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_vendor/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_vendor/cachecontrol/adapter.py", line 57, in send
#     resp = super(CacheControlAdapter, self).send(request, **kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_vendor/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#            ^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_vendor/urllib3/connectionpool.py", line 714, in urlopen
#     httplib_response = self._make_request(
#                        ^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_vendor/urllib3/connectionpool.py", line 403, in _make_request
#     self._validate_conn(conn)
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_vendor/urllib3/connectionpool.py", line 1053, in _validate_conn
#     conn.connect()
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_vendor/urllib3/connection.py", line 363, in connect
#     self.sock = conn = self._new_conn()
#                        ^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_vendor/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages/pip/_vendor/urllib3/util/connection.py", line 72, in create_connection
#     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mac/anaconda3/envs/tf/lib/python3.11/socket.py", line 962, in getaddrinfo
#     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (4.66.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (0.4.20)
# Requirement already satisfied: libclang>=13.0.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: numpy<1.24,>=1.22 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (68.0.0)
# Requirement already satisfied: six>=1.12.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (4.7.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (1.48.2)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (2.12.1)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.35.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from jax>=0.3.15->tensorflow) (0.3.1)
# Requirement already satisfied: scipy>=1.9 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from jax>=0.3.15->tensorflow) (1.11.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.6.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.7.2)
# Requirement already satisfied: urllib3<2.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: librosa in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from librosa) (1.23.5)
# Requirement already satisfied: scipy>=1.2.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from librosa) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=0.14 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from librosa) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from librosa) (4.7.1)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: packaging>=20.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from pooch>=1.0->librosa) (23.1)
# Requirement already satisfied: requests>=2.19.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (1.11.1)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from scipy) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pydub in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (0.25.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: resampy in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (0.4.2)
# Requirement already satisfied: numpy>=1.17 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from resampy) (1.23.5)
# Requirement already satisfied: numba>=0.53 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from resampy) (0.58.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from numba>=0.53->resampy) (0.41.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
#path to your csv file of balanced data
balanced_data_path = "/Users/mac/Desktop/data/data/Balanced_data.csv"

#path to the cv-other-train folder of the common voice database downloaded
training_data_path = "/Users/mac/Desktop/archive/cv-other-train" + "/"


#path to the cv-other-dev folder of the common voice database downloaded
example_data_path = "/Users/mac/Desktop/archive/cv-other-dev" + "/"

# %%
import numpy as np 
import scipy
import pandas as pd 
import csv
import os
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from sklearn.model_selection import train_test_split
import os
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, EarlyStopping
from tqdm import tqdm

import glob
import shutil
from pydub import AudioSegment
import librosa

# %% [markdown]
# ## Second try using Mel spectrogram Frequency, MFCC, Chroma, Contrast and Tonnetz

# %% [markdown]
# ## Using Pydub.AudioSegment : It works

# %% [markdown]
# #### Fixing the sample rate issue

# %%
# %pip install resampy
# Out:
# Collecting resampy
#   Downloading resampy-0.4.2-py3-none-any.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 5.3 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.17 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from resampy) (1.23.5)
# Requirement already satisfied: numba>=0.53 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from resampy) (0.58.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /Users/mac/anaconda3/envs/tf/lib/python3.11/site-packages (from numba>=0.53->resampy) (0.41.1)
# Installing collected packages: resampy
# Successfully installed resampy-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import resampy

def resample(audio_file, target_sr):
    x, sr_orig = librosa.load(audio_file, sr=None, mono=False)
    audio_data = resampy.resample(audio_data, sr_orig, target_sr)

# %%
def extract_feature(file_name, **kwargs):
    """
    Extract feature from audio file `file_name`
        Features supported:
            - MFCC (mfcc)
            - Chroma (chroma)
            - MEL Spectrogram Frequency (mel)
            - Contrast (contrast)
            - Tonnetz (tonnetz)
    """
    mfcc = kwargs.get("mfcc")
    chroma = kwargs.get("chroma")
    mel = kwargs.get("mel")
    contrast = kwargs.get("contrast")
    tonnetz = kwargs.get("tonnetz")

    # Load the audio file with pydub
    audio = AudioSegment.from_file(file_name)
    sample_rate = audio.frame_rate

    # Convert to NumPy array
    audio_data = np.array(audio.get_array_of_samples())
    if audio.channels == 2:  # Check if stereo and convert to mono
        audio_data = audio_data.reshape((-1, 2))
        audio_data = audio_data.mean(axis=1)
    audio_data = audio_data.astype(np.float32) / np.iinfo(audio_data.dtype).max  # Normalize

    # Feature extraction
    result = np.array([])
    if chroma or contrast or tonnetz:
        stft = np.abs(librosa.stft(audio_data))
    
    if mfcc:
        mfccs = np.mean(librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=13).T, axis=0)
        result = np.hstack((result, mfccs))

    if chroma:
        chroma_feature = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
        result = np.hstack((result, chroma_feature))

    if mel:
        mel_feature = np.mean(librosa.feature.melspectrogram(y=audio_data, sr=sample_rate).T, axis=0)
        result = np.hstack((result, mel_feature))

    if contrast:
        contrast_feature = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T, axis=0)
        result = np.hstack((result, contrast_feature))

    if tonnetz:
        tonnetz_feature = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(audio_data), sr=sample_rate).T, axis=0)
        result = np.hstack((result, tonnetz_feature))

    return result

# %% [markdown]
# ### Once we have a good Balanced_data.csv containing paths to the audios.mp3 + their labels, saved in a folder named Data, we extract their features

# %% [markdown]
# ### Loading the data, spliting into train-test-validation, defining the Model

# %%
def load_data(vector_length=128):
    """A function to load gender recognition dataset from `data` folder
    After the second run, this will load from results/features.npy and results/labels.npy files
    as it is much faster!"""
    # make sure results folder exists
    if not os.path.isdir("results"):
        os.mkdir("results")
    # if features & labels already loaded individually and bundled, load them from there instead
    if os.path.isfile("results/features.npy") and os.path.isfile("results/labels.npy"):
        X = np.load("results/features.npy")
        y = np.load("results/labels.npy")
        return X, y
    # read dataframe
    df = pd.read_csv(balanced_data_path)
    # get total samples
    n_samples = len(df)
    # get total male samples
    n_male_samples = len(df[df['gender'] == 0])
    # get total female samples
    n_female_samples = len(df[df['gender'] == 1])
    print("Total samples:", n_samples)
    print("Total male samples:", n_male_samples)
    print("Total female samples:", n_female_samples)
    # initialize an empty array for all audio features
    X = np.zeros((n_samples, vector_length))
    # initialize an empty array for all audio labels (1 for male and 0 for female)
    y = np.zeros((n_samples, 1))
    for i, (filename, gender) in tqdm(enumerate(zip(df['filename'], df['gender'])), "Loading data", total=n_samples):

        features = extract_feature(training_data_path + filename,  mel = True)
        X[i] = features
        y[i] = gender

    # save the audio features and labels into files
    # so we won't load each one of them next run
    np.save("results/features", X)
    np.save("results/labels", y)
    return X, y


def split_data(X, y, test_size=0.1, valid_size=0.1):
    # split training set and testing set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=7)
    # split training set and validation set
    X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=valid_size, random_state=7)
    # return a dictionary of values
    return {
        "X_train": X_train,
        "X_valid": X_valid,
        "X_test": X_test,
        "y_train": y_train,
        "y_valid": y_valid,
        "y_test": y_test
    }


def create_model(vector_length=128):
    """5 hidden dense layers from 256 units to 64, not the best model, but why not."""
    model = Sequential()
    model.add(Dense(256, input_shape=(vector_length,)))
    model.add(Dropout(0.3))
    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.3))
    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.3))
    model.add(Dense(128, activation="relu"))
    model.add(Dropout(0.3))
    model.add(Dense(64, activation="relu"))
    model.add(Dropout(0.3))
    # one output neuron with sigmoid activation function, 0 means female, 1 means male
    model.add(Dense(1, activation="sigmoid"))
    # using binary crossentropy as it's male/female classification (binary)
    model.compile(loss="binary_crossentropy", metrics=["accuracy"], optimizer="adam")
    # print summary of the model
    model.summary()
    return model

# %%
# load the dataset
X, y = load_data()
print(X)
# split the data into training, validation and testing sets
data = split_data(X, y, test_size=0.1, valid_size=0.1)
# construct the model
model = create_model()

# use tensorboard to view metrics
tensorboard = TensorBoard(log_dir="logs")
# define early stopping to stop training after 5 epochs of not improving
early_stopping = EarlyStopping(mode="min", patience=5, restore_best_weights=True)

batch_size = 64
epochs = 100

# train the model using the training set and validating using validation set
model.fit(data["X_train"], data["y_train"], epochs=epochs, batch_size=batch_size, validation_data=(data["X_valid"], data["y_valid"]),
          callbacks=[tensorboard, early_stopping])


# save the model to a file
model.save("results/model.h5")

# evaluating the model using the testing set
print(f"Evaluating the model using {len(data['X_test'])} samples...")
loss, accuracy = model.evaluate(data["X_test"], data["y_test"], verbose=0)
print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")
# Out:
# [[7.14310864e-03 1.61338057e-02 2.30557639e-02 ... 2.54096366e-09
#   2.48413712e-09 2.43777998e-09]
#  [6.23296248e-03 2.46039266e-03 5.73755614e-03 ... 2.53370858e-09
#   2.49579712e-09 2.53083354e-09]
#  [9.16805002e-04 2.04855460e-03 1.92967569e-03 ... 2.49615750e-09
#   2.46899279e-09 2.52861510e-09]
#  ...
#  [8.76070652e-03 1.24021536e-02 2.79637665e-01 ... 2.58005972e-09
#   2.63226174e-09 2.61906941e-09]
#  [1.70558915e-01 4.28008175e+00 1.27596388e+01 ... 2.52021515e-09
#   2.64013122e-09 2.65393796e-09]
#  [7.96847194e-02 1.80307794e+00 1.50008879e+01 ... 2.42274423e-09
#   2.47013765e-09 2.49715715e-09]]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               33024
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 256)               65792
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 156,545
# Trainable params: 156,545
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 294/294 [==============================] - 8s 13ms/step - loss: 0.6418 - accuracy: 0.7173 - val_loss: 0.5152 - val_accuracy: 0.7897
# Epoch 2/100
# 294/294 [==============================] - 3s 9ms/step - loss: 0.4863 - accuracy: 0.8077 - val_loss: 0.4088 - val_accuracy: 0.8304
# Epoch 3/100
# 294/294 [==============================] - 3s 9ms/step - loss: 0.4265 - accuracy: 0.8270 - val_loss: 0.3721 - val_accuracy: 0.8448
# Epoch 4/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.4060 - accuracy: 0.8355 - val_loss: 0.3369 - val_accuracy: 0.8687
# Epoch 5/100
# 294/294 [==============================] - 2s 7ms/step - loss: 0.3728 - accuracy: 0.8493 - val_loss: 0.3263 - val_accuracy: 0.8563
# Epoch 6/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.3613 - accuracy: 0.8568 - val_loss: 0.3188 - val_accuracy: 0.8711
# Epoch 7/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.3533 - accuracy: 0.8601 - val_loss: 0.3185 - val_accuracy: 0.8725
# Epoch 8/100
# 294/294 [==============================] - 2s 7ms/step - loss: 0.3552 - accuracy: 0.8611 - val_loss: 0.3162 - val_accuracy: 0.8740
# Epoch 9/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.3463 - accuracy: 0.8644 - val_loss: 0.3024 - val_accuracy: 0.8855
# Epoch 10/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.3382 - accuracy: 0.8683 - val_loss: 0.2825 - val_accuracy: 0.8903
# Epoch 11/100
# 294/294 [==============================] - 2s 7ms/step - loss: 0.3279 - accuracy: 0.8738 - val_loss: 0.2958 - val_accuracy: 0.8826
# Epoch 12/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.3224 - accuracy: 0.8762 - val_loss: 0.2821 - val_accuracy: 0.8936
# Epoch 13/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.3201 - accuracy: 0.8767 - val_loss: 0.2947 - val_accuracy: 0.8946
# Epoch 14/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.3134 - accuracy: 0.8768 - val_loss: 0.2709 - val_accuracy: 0.8951
# Epoch 15/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.3050 - accuracy: 0.8843 - val_loss: 0.2843 - val_accuracy: 0.8922
# Epoch 16/100
# 294/294 [==============================] - 3s 8ms/step - loss: 0.3080 - accuracy: 0.8788 - val_loss: 0.2948 - val_accuracy: 0.8850
# Epoch 17/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.2992 - accuracy: 0.8866 - val_loss: 0.2705 - val_accuracy: 0.8955
# Epoch 18/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.2943 - accuracy: 0.8873 - val_loss: 0.2659 - val_accuracy: 0.9013
# Epoch 19/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.2874 - accuracy: 0.8890 - val_loss: 0.2816 - val_accuracy: 0.8999
# Epoch 20/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.2915 - accuracy: 0.8868 - val_loss: 0.2680 - val_accuracy: 0.9013
# Epoch 21/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.2860 - accuracy: 0.8919 - val_loss: 0.2759 - val_accuracy: 0.8965
# Epoch 22/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.2867 - accuracy: 0.8900 - val_loss: 0.2758 - val_accuracy: 0.8931
# Epoch 23/100
# 294/294 [==============================] - 2s 8ms/step - loss: 0.2804 - accuracy: 0.8933 - val_loss: 0.2715 - val_accuracy: 0.9018
# Evaluating the model using 2319 samples...
# Loss: 0.2813
# Accuracy: 90.30%

# %% [markdown]
# ## Prediction

# %%
from tensorflow.keras.models import load_model

def preprocess_audio(file_path):
    # Extract the same features as you did for training
    features = extract_feature(file_path, mel=True)
    return features

def predict_gender(file_path, model):
    # Preprocess the file
    features = preprocess_audio(file_path)
    # Reshape features to match the input shape of the model
    features = np.reshape(features, (1, -1))
    # Make a prediction
    prediction = model.predict(features)[0]
    # Interpret the result
    if prediction <= 0.5:
        return "Female",prediction
    else:
        return "Male",prediction

# Load the model
model = load_model("results/model.h5")

# Path to the new audio file
file_path = example_data_path + "cv-other-dev/sample-000001.mp3"

# Predict the gender
gender = predict_gender(file_path, model)
print(f"The predicted gender is: {gender}")
# Out:
# 1/1 [==============================] - 0s 200ms/step
# The predicted gender is: ('Male', array([0.786178], dtype=float32))
